# %% [markdown]
# <a href="https://colab.research.google.com/github/daniel2007skt-create/AP005-3-2026-3/blob/main/Corte1/Tarea3/Diccionarios2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DICCIONARIOS 2

# %% [markdown]
# # define el diccionario de alturas de edificios

# %%
building_heights = {"Burj Khalifa": 828, "Shanghai Tower": 632, "Abraj Al Bait": 601, "Ping An": 599, "Lotte World Tower": 554.5, "One World Trade": 541.3}

# %% [markdown]
# # imprime la altura de Burj Khalifa accediendo por clave

# %%
print(building_heights["Burj Khalifa"])

# %% [markdown]
# # imprime la altura de Ping An accediendo por clave

# %%
print(building_heights["Ping An"])

# %% [markdown]
# # define el diccionario de elementos del zodiaco con listas de signos

# %%
zodiac_elements = {"water": ["Cancer", "Scorpio", "Pisces"], "fire": ["Aries", "Leo", "Sagittarius"], "earth": ["Taurus", "Virgo", "Capricorn"], "air":["Gemini", "Libra", "Aquarius"]}

# %% [markdown]
# # imprime los signos del elemento tierra

# %%
print(zodiac_elements["earth"])

# %% [markdown]
# # imprime los signos del elemento fuego

# %%
print(zodiac_elements["fire"])

# %% [markdown]
# # redefine el diccionario de alturas de edificios

# %%
building_heights = {"Burj Khalifa": 828, "Shanghai Tower": 632, "Abraj Al Bait": 601, "Ping An": 599, "Lotte World Tower": 554.5, "One World Trade": 541.3}

# %% [markdown]
# # intenta acceder a una clave inexistente generando KeyError

# %%
print(building_heights["Landmark 81"])

# %% [markdown]
# # asigna el nombre de la clave a verificar

# %%
key_to_check = "Landmark 81"

# %% [markdown]
# # evalua si la clave existe en el diccionario antes de acceder a ella

# %%
if key_to_check in building_heights:

# %% [markdown]
# # imprime la altura si la comprobacion fue exitosa

# %%
print(building_heights["Landmark 81"])

# %% [markdown]
# # redefine el diccionario de elementos zodiacales

# %%
zodiac_elements = {"water": ["Cancer", "Scorpio", "Pisces"], "fire": ["Aries", "Leo", "Sagittarius"], "earth": ["Taurus", "Virgo", "Capricorn"], "air":["Gemini", "Libra", "Aquarius"]}

# %% [markdown]
# # asigna un valor a la clave energy

# %%
zodiac_elements["energy"] = "Not a Zodiac element"

# %% [markdown]
# # evalua si la clave energy existe dentro del diccionario

# %%
if "energy" in zodiac_elements:

# %% [markdown]
# # imprime el valor asignado a la clave energy

# %%
print(zodiac_elements["energy"])

# %% [markdown]
# # redefine el diccionario de alturas de edificios

# %%
building_heights = {"Burj Khalifa": 828, "Shanghai Tower": 632, "Abraj Al Bait": 601, "Ping An": 599, "Lotte World Tower": 554.5, "One World Trade": 541.3}

# %% [markdown]
# # obtiene el valor de Shanghai Tower usando el metodo get

# %%
building_heights.get("Shanghai Tower")

# %% [markdown]
# # busca una clave inexistente de forma segura retornado None

# %%
building_heights.get("My House")

# %% [markdown]
# # define el diccionario de identificadores de usuario

# %%
user_ids = {"teraCoder": 100019, "pythonGuy": 182921, "samTheJavaMaam": 123112, "lyleLoop": 102931, "keysmithKeith": 129384}

# %% [markdown]
# # consulta el id de teraCoder mediante el metodo get

# %%
user_ids.get("teraCoder")

# %% [markdown]
# # comprueba si el valor devuelto por get es igual a None

# %%
if user_ids.get("teraCoder") == None:

# %% [markdown]
# # asigna un valor por defecto si la clave no existia

# %%
tc_id = 1000

# %% [markdown]
# # establece la alternativa en caso de que la clave si exista

# %%
else:

# %% [markdown]
# # obtiene el valor de teraCoder si la clave fue encontrada

# %%
tc_id = user_ids.get("teraCoder")

# %% [markdown]
# # imprime el id obtenido para teraCoder

# %%
print(tc_id)

# %% [markdown]
# # verifica si superStackSmash no existe en el diccionario

# %%
if user_ids.get("superStackSmash") == None:

# %% [markdown]
# # asigna un identificador por defecto a stack_id

# %%
stack_id = 100000

# %% [markdown]
# # imprime el valor final asignado a stack_id

# %%
print(stack_id)

# %% [markdown]
# # define el diccionario de rifa de premios

# %%
raffle = {223842: "Teddy Bear", 872921: "Concert Tickets", 320291: "Gift Basket", 412123: "Necklace", 298787: "Pasta Maker"}

# %% [markdown]
# # elimina el boleto 320291 e imprime el premio obtenido

# %%
print(raffle.pop(320291, "No Prize"))

# %% [markdown]
# # imprime el estado del diccionario tras remover el primer boleto

# %%
print(raffle)

# %% [markdown]
# # intenta eliminar un boleto inexistente retornando el mensaje por defecto

# %%
print(raffle.pop(100000, "No Prize"))

# %% [markdown]
# # imprime el diccionario confirmando que no sufrio cambios

# %%
print(raffle)

# %% [markdown]
# # remueve el boleto 872921 e imprime su valor

# %%
print(raffle.pop(872921, "No Prize"))

# %% [markdown]
# # muestra el diccionario final tras las eliminaciones

# %%
print(raffle)

# %% [markdown]
# # define el diccionario de items disponibles y sus puntos

# %%
available_items = {"health potion": 10, "cake of the cure": 5, "green elixir": 20, "strength sandwich": 25, "stamina grains": 15, "power stew": 30}

# %% [markdown]
# # establece los puntos de salud iniciales

# %%
health_points = 20

# %% [markdown]
# # suma los puntos de stamina grains extrayendolo del diccionario

# %%
health_points += available_items.pop("stamina grains", 0)

# %% [markdown]
# # remueve power stew y adiciona sus puntos a la salud

# %%
health_points += available_items.pop("power stew", 0)

# %% [markdown]
# # intenta remover mystic bread sumando cero al no existir

# %%
health_points += available_items.pop("mystic bread", 0)

# %% [markdown]
# # imprime los items que permanecen en el inventario

# %%
print(available_items)

# %% [markdown]
# # imprime el acumulado total de puntos de salud

# %%
print(health_points)

# %% [markdown]
# # define el diccionario de notas por estudiante

# %%
test_scores = {"Grace":[80, 72, 90], "Jeffrey":[88, 68, 81], "Sylvia":[80, 82, 84], "Pedro":[98, 96, 95], "Martin":[78, 80, 78], "Dina":[64, 60, 75]}

# %% [markdown]
# # convierte la vista de claves en una lista e imprime

# %%
print(list(test_scores))

# %% [markdown]
# # itera a traves de cada una de las claves del diccionario

# %%
for student in test_scores.keys():

# %% [markdown]
# # imprime el nombre del estudiante en cada iteracion

# %%
print(student)

# %% [markdown]
# # define el diccionario de identificadores de usuario

# %%
user_ids = {"teraCoder": 100019, "pythonGuy": 182921, "samTheJavaMaam": 123112, "lyleLoop": 102931, "keysmithKeith": 129384}

# %% [markdown]
# # define el diccionario con la cantidad de ejercicios por modulo

# %%
num_exercises = {"functions": 10, "syntax": 13, "control flow": 15, "loops": 22, "lists": 19, "classes": 18, "dictionaries": 18}

# %% [markdown]
# # extrae la vista de claves de los usuarios

# %%
users = user_ids.keys()

# %% [markdown]
# # extrae la vista de claves de los modulos

# %%
lessons = num_exercises.keys()

# %% [markdown]
# # imprime el objeto con las claves de usuarios

# %%
print(users)

# %% [markdown]
# # imprime el objeto con las claves de lecciones

# %%
print(lessons)

# %% [markdown]
# # redefine el diccionario con las listas de notas

# %%
test_scores = {"Grace":[80, 72, 90], "Jeffrey":[88, 68, 81], "Sylvia":[80, 82, 84], "Pedro":[98, 96, 95], "Martin":[78, 80, 78], "Dina":[64, 60, 75]}

# %% [markdown]
# # recorre los valores del diccionario de calificaciones

# %%
for score_list in test_scores.values():

# %% [markdown]
# # imprime la lista de calificaciones en cada iteracion

# %%
print(score_list)

# %% [markdown]
# # redefine el diccionario con la cantidad de ejercicios

# %%
num_exercises = {"functions": 10, "syntax": 13, "control flow": 15, "loops": 22, "lists": 19, "classes": 18, "dictionaries": 18}

# %% [markdown]
# # inicializa el contador de ejercicios totales

# %%
total_exercises = 0

# %% [markdown]
# # itera por cada uno de los valores numericos de ejercicios

# %%
for exercises in num_exercises.values():

# %% [markdown]
# # acumula la cantidad de ejercicios en la variable total

# %%
total_exercises += exercises

# %% [markdown]
# # imprime la suma final de todos los ejercicios

# %%
print(total_exercises)

# %% [markdown]
# # define el diccionario con la valuacion de grandes empresas

# %%
biggest_brands = {"Apple": 184, "Google": 141.7, "Microsoft": 80, "Coca-Cola": 69.7, "Amazon": 64.8}

# %% [markdown]
# # itera simultaneamente sobre la clave y el valor de cada marca

# %%
for company, value in biggest_brands.items():

# %% [markdown]
# # imprime una frase construida con la empresa y su valor

# %%
print(company + " has a value of " + str(value) + " billion dollars. ")

# %% [markdown]
# # define el diccionario de representacion femenina por profesion

# %%
pct_women_in_occupation = {"CEO": 28, "Engineering Manager": 9, "Pharmacist": 58, "Physician": 40, "Lawyer": 37, "Aerospace Engineer": 9}

# %% [markdown]
# # recorre cada par de ocupacion y porcentaje

# %%
for occupation, percentage in pct_women_in_occupation.items():

# %% [markdown]
# # imprime el mensaje formateado con los datos de la ocupacion

# %%
print("Women make up " + str(percentage) + " percent of " + occupation + "s.")
